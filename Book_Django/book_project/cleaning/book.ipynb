# %%
import pandas as pd

# %%
bookdetails=pd.read_csv("Book_Details.csv")

# %%
df=pd.DataFrame(bookdetails)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#        Unnamed: 0    book_id  \
# 0               0          1
# 1               1          2
# 2               2          3
# 3               3          5
# 4               4          6
# ...           ...        ...
# 16220       16220  208877606
# 16221       16221  208877648
# 16222       16222  209251042
# 16223       16223  209441121
# 16224       16224  209607645
#
#                                          cover_image_uri  \
# 0      https://images-na.ssl-images-amazon.com/images...
# 1      https://images-na.ssl-images-amazon.com/images...
# 2      https://images-na.ssl-images-amazon.com/images...
# 3      https://images-na.ssl-images-amazon.com/images...
# 4      https://images-na.ssl-images-amazon.com/images...
# ...                                                  ...
# 16220  https://images-na.ssl-images-amazon.com/images...
# 16221  https://images-na.ssl-images-amazon.com/images...
# 16222  https://images-na.ssl-images-amazon.com/images...
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# book_id                 0
# cover_image_uri         0
# book_title              0
# book_details           48
# format                  0
# publication_info        0
# authorlink              0
# author                  0
# num_pages               0
# genres                  0
# num_ratings             0
# num_reviews             0
# average_rating          0
# rating_distribution     0
# dtype: int64

# %%
df["book_details"].isnull().sum()
# Out:
# 48

# %%
df[df["book_details"].isnull()]
# Out:
#        Unnamed: 0    book_id  \
# 4836         4836     143045
# 4909         4909     148831
# 5269         5269     185368
# 6812         6812     447996
# 7231         7231     584330
# 7246         7246     588704
# 7439         7439     656044
# 8307         8307    1105192
# 8709         8709    1596070
# 8710         8710    1596770
# 8830         8830    1784319
# 8980         8980    1983803
# 9225         9225    2278912
# 9317         9317    2367232
# 9368         9368    2444508
# 9374         9374    2455019
# 9442         9442    2569496
# 9443         9443    2570269
# 9820         9820    3149357
# 9971         9971    3334967
# 10050       10050    3454024
# 10265       10265    4313803
# 10284       10284    4415879
# 10410       10410    4983620
# 10449       10449    5167246
# 10646       10646    6056726
# 11205       11205    6921351
# 11601       11601    8060827
# 11709       11709    8549857
# 11862       11862    9482800
# 12440       12440   13002545
# ...

# %%
max_num=df.sort_values(by=['num_ratings'],ascending=False)

# %%
avg_max=df['average_rating'].max()

# %%
df[avg_max==max_num['average_rating']].count()
# Out:
# C:\Users\ragavi.v\AppData\Local\Temp\ipykernel_6868\2380413609.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[avg_max==max_num['average_rating']].count()
# Unnamed: 0             35
# book_id                35
# cover_image_uri        35
# book_title             35
# book_details           29
# format                 35
# publication_info       35
# authorlink             35
# author                 35
# num_pages              35
# genres                 35
# num_ratings            35
# num_reviews            35
# average_rating         35
# rating_distribution    35
# dtype: int64

# %%
top_data=df[avg_max==max_num['average_rating']]
# Out:
# C:\Users\ragavi.v\AppData\Local\Temp\ipykernel_6868\1753737046.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   top_data=df[avg_max==max_num['average_rating']]

# %%
top_data.sort_values(by=['num_ratings'],ascending=False).head(5)
# Out:
#        Unnamed: 0   book_id  \
# 15003       15003  41009603
# 14791       14791  37757785
# 13059       13059  17259227
# 15845       15845  60159710
# 14794       14794  37800210
#
#                                          cover_image_uri  \
# 15003  https://images-na.ssl-images-amazon.com/images...
# 14791  https://images-na.ssl-images-amazon.com/images...
# 13059  https://images-na.ssl-images-amazon.com/images...
# 15845  https://images-na.ssl-images-amazon.com/images...
# 14794  https://images-na.ssl-images-amazon.com/images...
#
#                                            book_title  \
# 15003  Elliptical door (A multifaceted overview) (US)
# 14791                                Armée des ombres
# 13059                                 Patience's Love
# 15845                  Anshuman krit Saral Vastu Gyan
# 14794                                  Gris Ange 2014
#
#                                             book_details  \
# ...

# %%
df.drop(columns='Unnamed: 0',inplace=True)

# %%
df_duplicates=df.drop_duplicates(subset=['book_id', 'cover_image_uri','book_title','book_details','format','publication_info','authorlink','author','num_pages','genres','average_rating'], keep='first')

# %%
df_duplicates.to_csv('cleaned1.csv',index=False)

# %%
df1=pd.read_csv('cleaned1.csv')

# %%
df1['num_pages'] = df1['num_pages'].str.extract(r"\['(\d+)'\]").astype(str, errors='ignore')

# %%
df1['num_pages'].fillna('None',inplace=True)
# Out:
# C:\Users\ragavi.v\AppData\Local\Temp\ipykernel_6868\3268528519.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['num_pages'].fillna('None',inplace=True)

# %%
df1['genres'].replace('[]','None',inplace=True)
# Out:
# C:\Users\ragavi.v\AppData\Local\Temp\ipykernel_6868\1259324730.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['genres'].replace('[]','None',inplace=True)

# %%
df1['book_details'].fillna('None',inplace=True)
# Out:
# C:\Users\ragavi.v\AppData\Local\Temp\ipykernel_6868\3553400754.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['book_details'].fillna('None',inplace=True)

# %%
df1['format'].replace('[]','None',inplace=True)
# Out:
# C:\Users\ragavi.v\AppData\Local\Temp\ipykernel_6868\3599434035.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['format'].replace('[]','None',inplace=True)

# %%
df1['publication_info'].replace('[]','None',inplace=True)
# Out:
# C:\Users\ragavi.v\AppData\Local\Temp\ipykernel_6868\3742369430.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['publication_info'].replace('[]','None',inplace=True)

# %%
df1[df1['cover_image_uri'].str.contains(r'\.png')]
# Out:
#          book_id                                    cover_image_uri  \
# 4799      143045  https://dryofg8nmyqjw.cloudfront.net/images/no...
# 6942      508509  https://dryofg8nmyqjw.cloudfront.net/images/no...
# 7959      888214  https://dryofg8nmyqjw.cloudfront.net/images/no...
# 8208     1059967  https://dryofg8nmyqjw.cloudfront.net/images/no...
# 8485     1345137  https://dryofg8nmyqjw.cloudfront.net/images/no...
# 8572     1443350  https://dryofg8nmyqjw.cloudfront.net/images/no...
# 8651     1596770  https://dryofg8nmyqjw.cloudfront.net/images/no...
# 8740     1740631  https://dryofg8nmyqjw.cloudfront.net/images/no...
# 8770     1784319  https://dryofg8nmyqjw.cloudfront.net/images/no...
# 9355     2533529  https://dryofg8nmyqjw.cloudfront.net/images/no...
# 9430     2661772  https://dryofg8nmyqjw.cloudfront.net/images/no...
# 10085    3756794  https://dryofg8nmyqjw.cloudfront.net/images/no...
# 10219    4415879  https://dryofg8nmyqjw.cloudfront.net/images/no...
# ...

# %%
df1.loc[[4799], ['cover_image_uri']] = 'https://therealchrisparkle.com/2020/08/21/the-paul-berna-challenge-the-knights-of-king-midas-1958/91236597_228576601533249_211728590474051584_n/'

# %%
df1.loc[[6942], ['cover_image_uri']] = 'https://i.gr-assets.com/images/S/compressed.photo.goodreads.com/books/1450481151i/28241370._UX160_.jpg'

# %%
df1.loc[7959,'cover_image_uri'] = 'https://johnatkinsonbooks.co.uk/wp-content/uploads/2024/04/mordecai_richler_st_urbains_horseman_first_ed1.jpg'

# %%
df1.loc[8208,'cover_image_uri'] = "https://images.flandersliterature.be/bookcovers/31f03bb7b2902dd436c6b47f68d873c8.jpg?auto=format&fit=max&ixlib=php-1.1.0&q=65&w=600&s=b834524f71b709fb61d5d6f639c0174a"

# %%
df1.loc[8485,'cover_image_uri'] = "https://m.media-amazon.com/images/I/71g-IU-Ot+L._AC_UF1000,1000_QL80_.jpg"

# %%
df1.loc[8572,'cover_image_uri'] = "https://m.media-amazon.com/images/I/71dfcsnaRiL._AC_UF1000,1000_QL80_.jpg"

# %%
df1.loc[8651,'cover_image_uri'] = "https://m.media-amazon.com/images/I/71ThxoH3zTL._AC_UF1000,1000_QL80_.jpg"

# %%
df1.loc[8740,'cover_image_uri'] = "https://m.media-amazon.com/images/I/71mYePKl3QL._AC_UF1000,1000_QL80_.jpg"

# %%
df1.loc[8770,'cover_image_uri'] = "https://m.media-amazon.com/images/I/71-o6iQhAKL._AC_UF1000,1000_QL80_.jpg"

# %%
df1.loc[9355,'cover_image_uri'] = "https://m.media-amazon.com/images/I/51JaFlK9LeL._AC_UF1000,1000_QL80_.jpg"

# %%
df1.loc[9430,'cover_image_uri'] = "https://m.media-amazon.com/images/I/61J8XeaIwZL._AC_UF1000,1000_QL80_.jpg"

# %%
df1.loc[10085,'cover_image_uri'] = "https://m.media-amazon.com/images/I/51nQrnFvnxL.jpg"

# %%
df1.loc[10219,'cover_image_uri'] = "https://m.media-amazon.com/images/I/41s1fQtPM0L.jpg"

# %%
df1.loc[10236,'cover_image_uri'] = "https://m.media-amazon.com/images/I/713zye8OZFL._AC_UF1000,1000_QL80_.jpg"

# %%
df1.loc[10239,'cover_image_uri'] = "https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1390178450i/6694479.jpg"

# %%
df1.loc[10344,'cover_image_uri'] = "https://m.media-amazon.com/images/I/31MycDKMzJL.jpg"

# %%
df1.loc[10415,'cover_image_uri'] = "https://m.media-amazon.com/images/I/91pVYIU7DDL._AC_UF1000,1000_QL80_.jpg"

# %%
df1.loc[10580,'cover_image_uri'] = "https://m.media-amazon.com/images/I/61w-+4arBBL._AC_UF1000,1000_QL80_.jpg"

# %%
df1.loc[10946,'cover_image_uri'] = "https://m.media-amazon.com/images/I/51MCQ4qHT1L.jpg"

# %%
df1.loc[10958,'cover_image_uri'] = "https://m.media-amazon.com/images/I/61e3kj7tV0L._AC_UF1000,1000_QL80_.jpg"

# %%
df1.loc[11022,'cover_image_uri'] = "https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1488733606i/34468388.jpg"

# %%
df1.loc[11117,'cover_image_uri'] = "https://pictures.abebooks.com/inventory/md/md31787468106.jpg"

# %%
df1.loc[11321,'cover_image_uri'] = "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQjCjxJxe9VoeIkWhHt6FUvmVW-G3KzgFxHVg&s"

# %%
df1.loc[11604,'cover_image_uri'] = "https://m.media-amazon.com/images/I/61N+Ow00lhL._AC_UF1000,1000_QL80_.jpg"

# %%
df1.loc[11888,'cover_image_uri'] = "https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1323868376i/5479161.jpg"

# %%
df1.loc[12114,'cover_image_uri'] = "https://m.media-amazon.com/images/I/51xTx4+aU7L._AC_UF1000,1000_QL80_.jpg"

# %%
df1.loc[12720,'cover_image_uri'] = "https://eon.ge/wp-content/uploads/2021/04/20799471.jpg"

# %%
df1.loc[12762,'cover_image_uri'] = "https://m.media-amazon.com/images/I/71jES03fOGL._AC_UF1000,1000_QL80_.jpg"

# %%
df1.loc[12970,'cover_image_uri'] = "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT2BlsVdfqugUdr6BLCmD5zvQ22k6Ref9gkTQ&s"

# %%
df1.loc[13531,'cover_image_uri'] = "https://m.media-amazon.com/images/I/71jZbHCCI4L._AC_UF1000,1000_QL80_.jpg"

# %%
df1.loc[13608,'cover_image_uri'] = "https://m.media-amazon.com/images/I/71wcUbrnKOL._AC_UF1000,1000_QL80_.jpg"

# %%
df1.loc[13745,'cover_image_uri'] = "https://ludopedio.org.br/wp-content/uploads/fla-flu.jpeg"

# %%
df1.loc[15266,'cover_image_uri'] = "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSPakoPravOWoLgxjlOlSd6iprKm2I2lbwF4A&s"

# %%
df1.loc[15398,'cover_image_uri'] = "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSDE00-7N7PSua4bTluZhe17p8kUm0871hmXw&s"

# %%
df1.loc[15825,'cover_image_uri'] = "https://i1.sndcdn.com/artworks-lLZybFbv855IKbNF-Hwd8rg-t500x500.jpg"

# %%
df1.loc[15827,'cover_image_uri'] = "https://pbs.twimg.com/media/FcCbBIVacAEypBm.jpg"

# %%
df1.loc[15862,'cover_image_uri'] = "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQvx5kWFB51i1tHIrsMttin-gca1wUideA5vg&s"

# %%
df1.loc[16059,'cover_image_uri'] = "https://images-na.ssl-images-amazon.com/images/S/compressed.photo.goodreads.com/books/1681868597i/59784480.jpg"

# %%
df1[df1["cover_image_uri"].str.contains(".*png.*")]
# Out:
# Empty DataFrame
# Columns: [book_id, cover_image_uri, book_title, book_details, format, publication_info, authorlink, author, num_pages, genres, num_ratings, num_reviews, average_rating, rating_distribution]
# Index: []

# %%
df1.to_csv('cleaned2.csv',index=False)

# %%
df1.rename(columns={'cover_image_uri':'cover_image_url'},inplace=True)

# %%
df1['format'] = df1['format'].str.replace("'", '"')

# %%
df1['publication_info'] = df1['publication_info'].str.replace("'", '"')

# %%
df1['genres'] = df1['genres'].str.replace("'", '"')

# %%
df1['rating_distribution'] = df1['rating_distribution'].str.replace("'", '"')

# %%
df1['book_details'] = df1['book_details'].str.replace(r'[^\x00-\x7F]+', '', regex=True)

# %%
df1.isna().sum()
# Out:
# book_id                0
# cover_image_url        0
# book_title             0
# book_details           0
# format                 0
# publication_info       0
# authorlink             0
# author                 0
# num_pages              0
# genres                 0
# num_ratings            0
# num_reviews            0
# average_rating         0
# rating_distribution    0
# dtype: int64

# %%
arr1=df1['author'].nunique()

# %%
arr1
# Out:
# 7615

# %%
#pip install mysql.connector

# %%
# import mysql.connector
# db=mysql.connector.connect(host="3.7.198.191",
#                            user="bu-trausr",
#                            password="r9*rwr$!usFw0MCPj#fJ",
#                            database="bu-training",
#                            port="8993",
#                            auth_plugin="mysql_native_password")

# cur=db.cursor()

# query1="""create table book_ragavi4(id int auto_increment primary key,book_id varchar(15) unique,cover_image_url varchar(200),book_title varchar(300),book_details text,book_format varchar(100),publication_info varchar(100),authorlink varchar(200),author varchar(100),num_pages varchar(50),genres varchar(300),num_ratings int,num_reviews int,average_rating float,rating_distribution json)"""

# cur.execute(query1)

# database1 = [(book_id, cover_image_url,book_title,book_details,book_format,publication_info,authorlink,author,num_pages,genres,int(num_ratings),int(num_reviews),float(average_rating),rating_distribution) for book_id, cover_image_url,book_title,book_details,book_format,publication_info,authorlink,author,num_pages,genres,num_ratings,num_reviews,average_rating,rating_distribution in df1.values]

# sql1 = """INSERT INTO book_ragavi4 (book_id, cover_image_url,book_title,book_details,book_format,publication_info,authorlink,author,num_pages,genres,num_ratings,num_reviews,average_rating,rating_distribution) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"""

# cur.executemany(sql1, database1)

# db.close()

# %%
from sqlalchemy import create_engine,text

engine = create_engine('mysql+pymysql://bu-trausr:r9*rwr$!usFw0MCPj#fJ@3.7.198.191:8993/bu-training')

create_table_sql = """
create table if not exists book_ragavi_priya(id int auto_increment primary key,
book_id varchar(15) unique,
cover_image_url varchar(200),
book_title varchar(300),
book_details text,
format varchar(100),
publication_info varchar(100),
authorlink varchar(200),
author varchar(100),
num_pages varchar(50),
genres varchar(300),
num_ratings int,
num_reviews int,
average_rating float,
rating_distribution varchar(300)
);
"""
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 from sqlalchemy import create_engine,text
#       3 engine = create_engine('mysql+pymysql://bu-trausr:r9*rwr$!usFw0MCPj#fJ@3.7.198.191:8993/bu-training')
#       5 create_table_sql = """
#       6 create table if not exists book_ragavi_priya(id int auto_increment primary key,
#       7 book_id varchar(15) unique,
#    (...)
#      21 );
#      22 """
#
# ModuleNotFoundError: No module named 'sqlalchemy'

# %%
# with engine.connect() as conn:
    # conn.execute(text(create_table_sql))

# %%
# df1.to_sql("book_ragavi_priya",con=engine,if_exists="append",index=False)
# Out:
# 16157
